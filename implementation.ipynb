# %%
from google.colab import drive
drive.mount('/content/drive', )
# Out:
# Mounted at /content/drive

# %%
#install dependencies
# !pip install -r /content/drive/MyDrive/NATOPS-TSC/requirements.txt
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json

# %%
# !pip install tslearn
# Out:
# ...
#   Using cached tslearn-0.6.3-py3-none-any.whl.metadata (14 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 12.4 MB/s eta 0:00:00
# ...

# %%
#preprocessing
# !python /content/drive/MyDrive/NATOPS-TSC/training/preprocess.py
# Out:
# y_train sample: ['4.0' '3.0' '3.0' '4.0' '3.0']
# y_train type: <class 'numpy.ndarray'>
# y_train dtype: <U3
# y_train after conversion: [3 2 2 3 2]
# y_train dtype after conversion: int64
# Batch X shape: torch.Size([32, 51, 24]), Batch y shape: torch.Size([32])

# %%
# !pip install utils
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for utils: filename=utils-1.0.2-py2.py3-none-any.whl size=13906 sha256=cce5cdb15678079683246a323378f17011e4166440fbf3f15466ca6cdbcf3172
#   Stored in directory: /root/.cache/pip/wheels/15/0c/b3/674aea8c5d91c642c817d4d630bd58faa316724b136844094d
# Successfully built utils
# ...

# %%
#training LSTM
# !python /content/drive/MyDrive/NATOPS-TSC/training/train.py
# Out:
# Using device: cuda
# Loaded X shape: torch.Size([180, 24, 51])
# Loaded y shape: torch.Size([180])
# Loaded X shape: torch.Size([180, 24, 51])
# Loaded y shape: torch.Size([180])
# Epoch [1/50], Loss: 1.7870
# Test Accuracy: 0.2889
# New best model saved with Test Accuracy: 0.2889
# Best Hyperparameters: {'hidden_dim': 64, 'num_layers': 2, 'bidirectional': False, 'learning_rate': 0.001}
#
# Epoch [2/50], Loss: 1.7654
# Test Accuracy: 0.3278
# New best model saved with Test Accuracy: 0.3278
# Best Hyperparameters: {'hidden_dim': 64, 'num_layers': 2, 'bidirectional': False, 'learning_rate': 0.001}
#
# Epoch [3/50], Loss: 1.7329
# Test Accuracy: 0.4667
# New best model saved with Test Accuracy: 0.4667
# Best Hyperparameters: {'hidden_dim': 64, 'num_layers': 2, 'bidirectional': False, 'learning_rate': 0.001}
#
# Epoch [4/50], Loss: 1.6647
# Test Accuracy: 0.4833
# New best model saved with Test Accuracy: 0.4833
# ...

# %%
# prompt: generate an infinite loop to keep my runtime alive

import time

while True:
  time.sleep(60) # Sleep for 60 seconds
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-6816bf2105b3> in <cell line: 0>()
#       4
#       5 while True:
# ----> 6   time.sleep(60) # Sleep for 60 seconds
#
# KeyboardInterrupt:
